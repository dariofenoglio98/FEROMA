# %%
import numpy as np
import torch
import pickle

# %%
                    client_distances_matrix = np.array(client_distances)
                    np.save(f'results/{self.path}/client_distances_matrix_round_{server_round}.npy', client_distances_matrix)
                    with open(f'results/{self.path}/client_cid_list_round_{server_round}.pkl', 'wb') as f:
                        pickle.dump(client_id_cid, f)
                        
                            np.save(f'./data/cur_datasets/client_distribution.npy', client_distribution)

# %%
for round in range(6,20):
    client_distances_matrix = np.load(f"/Users/dariofenoglio/Library/CloudStorage/OneDrive-USI/PC/Desktop/USI_Locale/dful/cfl_drift/results/42/LeNet5/MNIST/trDR_teND/client_cid_list_round_{round}.pkl")
        
        
        f'results/{self.path}/client_distances_matrix_round_{round}.npy')
    with open(f'results/{self.path}/client_cid_list_round_{round}.pkl', 'rb') as f:
        client_id_cid = pickle.load(f)

client_distribution = np.load(f'./data/cur_datasets/client_distribution.npy')

# %%
client_distribution = np.load("/Users/dariofenoglio/Library/CloudStorage/OneDrive-USI/PC/Desktop/USI_Locale/dful/data/cur_datasets/client_distribution.npy", allow_pickle=True)
client_distribution = print(client_distribution.item())
# Out:
# {0: [3, 4, 1, 3, 3], 1: [4, 1, 1, 3, 2], 2: [3, 3, 3, 3, 4], 3: [1, 4, 4, 4, 3], 4: [2, 1, 2, 4, 4], 5: [2, 2, 2, 4, 4], 6: [1, 1, 4, 2, 2], 7: [1, 4, 1, 1, 3], 8: [3, 3, 2, 4, 4], 9: [4, 4, 3, 2, 2], 10: [3, 2, 3, 4, 3], 11: [4, 4, 1, 3, 1], 12: [3, 3, 1, 1, 3], 13: [2, 4, 1, 4, 2], 14: [2, 2, 1, 2, 1], 15: [2, 4, 4, 3, 4], 16: [3, 4, 1, 4, 3], 17: [3, 2, 1, 4, 2], 18: [4, 4, 2, 2, 2], 19: [2, 2, 4, 2, 1]}
